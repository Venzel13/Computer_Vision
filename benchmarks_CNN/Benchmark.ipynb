# %% [markdown]
# # Memory, time and parameters comparisons of different CNN achitectures

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# This file might be downloaded from current directory

# %%
benchmarks = pd.read_csv('benchmarks.csv')

# %% [markdown]
# Time is measured in milliseconds and memory in bytes

# %%
benchmarks.sample(5)
# Out:
#         Model name  Number of parameters  Full pass time  Forward time  \
# 18    Densenet-201              20013928      114.708481     40.200191
# 2           VGG-13             133047848       43.235329     10.518528
# 5   VGG-11 with BN             132868840       35.546112      9.224192
# 10       ResNet-34              21797672       30.981119      6.978560
# 8   VGG-19 with BN             143678248       56.509441     15.490048
#
#     Full memory usage  Forward memory usage
# 18         1524014080            1383834112
# 2          2379568640            2305662464
# 5          2387257856            2304454144
# 10         1412838912            1415437824
# 8          2519715328            2392102400

# %%
benchmarks.plot.bar('Model name', subplots=True, figsize=(20, 20), legend=False);
